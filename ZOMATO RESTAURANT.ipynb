# %% [markdown]
# # IMPORTING IMPORTANT LIBRAIES

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # LOAD DATASET

# %%
df1=pd.read_csv('Zomato Restaurant.csv')
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df2=pd.read_excel(r'E:\data science internship\documents\COUNTRY.xlsx')
df2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
print("NUMBER OF ROW IN DATASET : ",df1.shape[0])
print("NUMBER OF COLUMNS IN DATASET : ",df1.shape[1])
# Out:
# NUMBER OF ROW IN DATASET :  9551
# NUMBER OF COLUMNS IN DATASET :  21

# %%
print("NUMBER OF ROW IN DATASET : ",df2.shape[0])
print("NUMBER OF COLUMNS IN DATASET : ",df2.shape[1])
# Out:
# NUMBER OF ROW IN DATASET :  15
# NUMBER OF COLUMNS IN DATASET :  2

# %% [markdown]
# # FEATURES OF DATASET

# %% [markdown]
# Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#  Country code
#  Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people

# %% [markdown]
# # COMBINE THE DATASET

# %%
df=pd.merge(df1,df2,right_index=True,left_index=True)
df
# Out:
#     Restaurant ID                           Restaurant Name  Country Code_x  \
# 0         6317637                          Le Petit Souffle             162
# 1         6304287                          Izakaya Kikufuji             162
# 2         6300002                    Heat - Edsa Shangri-La             162
# 3         6318506                                      Ooma             162
# 4         6314302                               Sambo Kojin             162
# 5        18189371                              Din Tai Fung             162
# 6         6300781                                Buffet 101             162
# 7         6301290                                   Vikings             162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila             162
# 9         6314987                                  Locavore             162
# 10        6309903                          Silantro Fil-Mex             162
# ...

# %% [markdown]
# # LET'S UNDERSTAND DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         15 non-null     int64
#  1   Restaurant Name       15 non-null     object
#  2   Country Code_x        15 non-null     int64
#  3   City                  15 non-null     object
#  4   Address               15 non-null     object
#  5   Locality              15 non-null     object
#  6   Locality Verbose      15 non-null     object
#  7   Longitude             15 non-null     float64
#  8   Latitude              15 non-null     float64
#  9   Cuisines              15 non-null     object
#  10  Average Cost for two  15 non-null     int64
#  11  Currency              15 non-null     object
#  12  Has Table booking     15 non-null     object
#  13  Has Online delivery   15 non-null     object
#  14  Is delivering now     15 non-null     object
# ...

# %% [markdown]
# OBSERVATION:-
#
#     * AS WE SEEN THEIR IS NO NULL VALUE IN THE DATASET
#
#     * MOST OF THE COLUMNS IN THE DATASET IS IN OBJECT DATATYPE

# %% [markdown]
# # LET'S CHECK NULL AND UNIQUE VALUE

# %%
df.isin(['NA','N/A','-',' ','?',' ?','�']).sum().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code_x          0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country Code_y          0
# Country                 0
# dtype: int64

# %%
df.nunique()
# Out:
# Restaurant ID           15
# Restaurant Name         14
# Country Code_x           1
# City                     6
# Address                 15
# Locality                10
# Locality Verbose        10
# Longitude               15
# Latitude                15
# Cuisines                13
# Average Cost for two    10
# Currency                 1
# Has Table booking        2
# Has Online delivery      1
# Is delivering now        1
# Switch to order menu     1
# Price range              2
# Aggregate rating         7
# Rating color             2
# Rating text              2
# Votes                   15
# Country Code_y          15
# Country                 15
# dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # START DATA VISUALIZATION

# %% [markdown]
# # 1.) UNIVARIATE ANALAYSIS

# %%
for i in df.columns:
    if df[i].dtype=='O':
        plt.figure(figsize=(15,9))
        sns.countplot(df[i])
        plt.xticks(fontweight="bold",rotation=55)
        plt.yticks(fontweight="bold")
    if df[i].dtype=='int64':
        plt.figure(figsize=(15,9))
        sns.distplot(df[i])
        plt.xticks(fontweight="bold")
        plt.yticks(fontweight="bold")

# %% [markdown]
# OBSERVATION:-
#
#     * SILANTRO FIL-MEX IS THE RESTAURANT NAME CAME HIGHEST TIME IN THE DATASET
#
#     * CITY WHISCH CAME HIGHEST TIME IN THE DATASET IS MANDALUYOUNG CITY
#
#     * Edsa Shangri-La, Ortigas, Mandaluyong City AND Sofitel Philippine Plaza Manila, Pasay City HAS CAME FREQUENTLY IN THE
#
#     DATASET
#
#     * Cuisines WHICH CAME HIGHEST IS DATASET IS Filipino AND Filipino, Mexican
#
#     * AVERAGE COST OF TWO IS AROUND 1700 IN THE DATASET
#
#     * MOST OF THE CUSTOMER BOOK THEIR TABLES
#
#     * HIGHEST PRICE RANGE OF MAXIMUM RESTAURANT IS 3.0
#
#     * MOST OF THE CUSTOMER CHOSEN DRAK GREEN COLOUR
#
#     * MAXIXMUM CUSTOMER GAVE EXCELLENT RATING IN THE DATASET

# %% [markdown]
# # 2.) BIVARIATE ANALAYSIS

# %%
pd.crosstab(df['City'],df['Price range'],margins=False).plot(kind='bar',figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='City'>

# %%
sns.pairplot(df)

# %% [markdown]
# # ENCODING OF DATAFRAME

# %% [markdown]
# WE HAVE LOT OF CATEGORICAL DATA IN DATADRAME SO WE NEED TO ENCODE DATA INTO NUMERICAL DATA SO WILL BE UNDERSTABLE BY MACHINE

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code_x  City  Address  Locality  \
# 0        6317637                5             162     0       12         1
# 1        6304287                4             162     0        9         5
# 2        6300002                3             162     1        7         2
# 3        6318506                8             162     1       14         6
# 4        6314302                9             162     1       13         6
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  \
# 0                 1  121.027535  14.565443         6  ...
# 1                 5  121.014101  14.553708         7  ...
# 2                 2  121.056831  14.581404        11  ...
# 3                 6  121.056475  14.585318         9  ...
# 4                 6  121.057508  14.584450         8  ...
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# 0                    0                  0                     0            3
# ...

# %% [markdown]
# # REMOVING OUTLIERS

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1
for i in df.columns:
    if plotnumber<=40:
        ax=plt.subplot(10,4,plotnumber)
        sns.boxplot(df[i],color='gold')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# AS WE SEEN THEIR IS NOT SO MUCH OUTLIERS

# %% [markdown]
# # seprating the columns into feature and target

# %% [markdown]
# 1.) PRICE RANGE

# %%
x=df.drop('Price range',axis=1)

# %%
y=df["Price range"]

# %% [markdown]
# # SCALING BY MIN MAX SCALING

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
X=mms.fit_transform(x)

# %% [markdown]
# # MACHIME LEARNING MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# # SELECT BEST RANDOM STATE

# %%
lin_reg=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=i)
    lin_reg.fit(x_train,y_train)
    pred_train=lin_reg.predict(x_train)
    pred_test=lin_reg.predict(x_test)
    print(f'At random state{i}, The training accuracy is : {r2_score(y_train,pred_train)}')
    print(f'At random state{i}, The test accuracy is : {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is : 1.0
# At random state0, The test accuracy is : -7.554626131424802
#
#
# At random state1, The training accuracy is : 1.0
# At random state1, The test accuracy is : -14.872964463727907
#
#
# At random state2, The training accuracy is : 1.0
# At random state2, The test accuracy is : -4513690.34724519
#
#
# At random state3, The training accuracy is : 1.0
# At random state3, The test accuracy is : -1.4580610279164543
#
#
# At random state4, The training accuracy is : 1.0
# At random state4, The test accuracy is : -3.7401056441123925
#
#
# At random state5, The training accuracy is : 1.0
# At random state5, The test accuracy is : -4282410.047323566
#
#
# At random state6, The training accuracy is : 1.0
# At random state6, The test accuracy is : -3.2312966629577833
#
#
# At random state7, The training accuracy is : 1.0
# At random state7, The test accuracy is : -22058.704111557952
#
#
# At random state8, The training accuracy is : 1.0
# ...

# %% [markdown]
# AS WE CONCLUDE THAT 92 STATE GAVE HIGHEST VALUE, SO TAKE 92 AS RANDOM STATE

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=92,test_size=0.33)

# %%
x_train.shape
# Out:
# (10, 22)

# %%
y_train.shape
# Out:
# (10,)

# %%
x_test.shape
# Out:
# (5, 22)

# %%
y_test.shape
# Out:
# (5,)

# %% [markdown]
# # 1.) LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train, y_train)
pred=lr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 68.92456970474878
# Mean squared error : 23342.322713381225
# Root Mean squared error : 152.78194498493997
#  R2 Score :
# 0.0

# %%
score=cross_val_score(lr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',lr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -173808.58023263686
# Difference in R2 & CV Score: 17380858.023263685

# %% [markdown]
# # 2.) SGD

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 6.005651845083551e+22
# Mean squared error : 4.684968414364448e+45
# Root Mean squared error : 6.844682910379741e+22
#  R2 Score :
# 0.0

# %%
score=cross_val_score(sgd,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',sgd,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : SGDRegressor() :
#
# Mean CV Score : -3.1140344357600046e+45
# Difference in R2 & CV Score: 3.1140344357600046e+47

# %% [markdown]
# # 3.) RANDOM FOREST REGRESSION

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred=rfr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 0.21800000000000005
# Mean squared error : 0.06726000000000003
# Root Mean squared error : 0.2593453296282777
#  R2 Score :
# 0.0

# %%
score=cross_val_score(rfr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',rfr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : -0.20243000000000005
# Difference in R2 & CV Score: 20.243000000000006

# %% [markdown]
# # 4.)DECISION TREE REGRESSION

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 0.0
# Mean squared error : 0.0
# Root Mean squared error : 0.0
#  R2 Score :
# 100.0

# %%
score=cross_val_score(dtr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',dtr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.4000000000000001
# Difference in R2 & CV Score: 59.99999999999999

# %% [markdown]
# # 5.) EXTRA TREE REGRESSION

# %%
etc=ExtraTreesRegressor()
etc.fit(x_train,y_train)
pred=etc.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 0.31800000000000006
# Mean squared error : 0.17930000000000001
# Root Mean squared error : 0.4234383071948026
#  R2 Score :
# 0.0

# %%
score=cross_val_score(etc,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',etc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : -0.29195
# Difference in R2 & CV Score: 29.195

# %% [markdown]
# # 6.)XGBOOST REGRESSION

# %%
xg=XGBRegressor()
xg.fit(x_train,y_train)
pred=xg.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 0.0003952980041503906
# Mean squared error : 1.5626051208528224e-07
# Root Mean squared error : 0.0003952980041503906
#  R2 Score :
# 0.0

# %%
score=cross_val_score(xg,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',xg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None) :
#
# Mean CV Score : -0.1997975374181407
# Difference in R2 & CV Score: 19.979753741814072

# %% [markdown]
# # HYPER PARAMETER TUNING: GRIDSEARCHCV

# %%
from sklearn.model_selection import GridSearchCV

# Create a decision tree regressor
regressor = DecisionTreeRegressor()

# Define the hyperparameter grid
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Perform grid search cross-validation
grid_search = GridSearchCV(regressor, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

# Evaluate the model with the best hyperparameters on the test set
best_regressor = grid_search.best_estimator_
test_score = best_regressor.score(x_test, y_test)
print("Test Score:", test_score)
# Out:
# Best Hyperparameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Score: 0.8
# Test Score: 1.0

# %%
dt = DecisionTreeRegressor(max_depth=15, max_features='log2',min_samples_leaf=2,min_samples_split=2)

# Train the model on the entire training dataset
dt.fit(x_train, y_train)

# Make predictions on new data
y_pred = dt.predict(x_test)

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib
joblib.dump(dt,"zomato_price_range_DATASET.pkl")
# Out:
# ['zomato_price_range_DATASET.pkl']

# %% [markdown]
# # PREDICTION

# %%
model = joblib.load("zomato_price_range_DATASET.pkl")

# Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([3., 3., 3., 3., 3.])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#              0    1    2    3    4
# Predicted  3.0  3.0  3.0  3.0  3.0
# Original   3.0  3.0  3.0  3.0  3.0

# %% [markdown]
# # seprating the columns into feature and target

# %% [markdown]
# 2.) Average Cost for two

# %%
x=df.drop('Average Cost for two',axis=1)

# %%
y=df['Average Cost for two']

# %% [markdown]
# # SCALING BY MIN MAX SCALING

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
X=mms.fit_transform(x)

# %% [markdown]
# # MACHIME LEARNING MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# # SELECT BEST RANDOM STATE

# %%
lin_reg=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=i)
    lin_reg.fit(x_train,y_train)
    pred_train=lin_reg.predict(x_train)
    pred_test=lin_reg.predict(x_test)
    print(f'At random state{i}, The training accuracy is : {r2_score(y_train,pred_train)}')
    print(f'At random state{i}, The test accuracy is : {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is : 1.0
# At random state0, The test accuracy is : -2.0482412673196144
#
#
# At random state1, The training accuracy is : 1.0
# At random state1, The test accuracy is : -27.699674047465326
#
#
# At random state2, The training accuracy is : 1.0
# At random state2, The test accuracy is : -37183041.16859279
#
#
# At random state3, The training accuracy is : 1.0
# At random state3, The test accuracy is : -21.279661901507097
#
#
# At random state4, The training accuracy is : 1.0
# At random state4, The test accuracy is : -289.3603890227661
#
#
# At random state5, The training accuracy is : 1.0
# At random state5, The test accuracy is : -961193.1241561916
#
#
# At random state6, The training accuracy is : 1.0
# At random state6, The test accuracy is : -14.3982797082657
#
#
# At random state7, The training accuracy is : 1.0
# At random state7, The test accuracy is : -1631.4955188321217
#
#
# At random state8, The training accuracy is : 1.0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=99,test_size=0.33)

# %%
x_train.shape
# Out:
# (10, 22)

# %%
y_train.shape
# Out:
# (10,)

# %%
x_test.shape
# Out:
# (5, 22)

# %%
y_test.shape
# Out:
# (5,)

# %% [markdown]
# # 1.) LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train, y_train)
pred=lr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 99.42594470768192
# Mean squared error : 14322.207939009046
# Root Mean squared error : 119.67542746532826
#  R2 Score :
# -66951.53529498616

# %%
score=cross_val_score(lr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',lr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -15856005.5170482
# Difference in R2 & CV Score: 1585533600.1695251

# %% [markdown]
# # 2.) SGD

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 8.395919051760807e+22
# Mean squared error : 7.049151423215125e+45
# Root Mean squared error : 8.395922476544865e+22
#  R2 Score :
# -3.300164523977118e+46

# %%
score=cross_val_score(sgd,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',sgd,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : SGDRegressor() :
#
# Mean CV Score : -2.552990196603707e+45
# Difference in R2 & CV Score: 2.2229737442059955e+47

# %% [markdown]
# # 3.) RANDOM FOREST REGRESSION

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred=rfr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.462000000000001
# Mean squared error : 34.070260000000005
# Root Mean squared error : 5.836973530863405
#  R2 Score :
# -59.50496254681647

# %%
score=cross_val_score(rfr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',rfr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : -7.664616644145362
# Difference in R2 & CV Score: 706.9567018677196

# %% [markdown]
# # 4.)DECISION TREE REGRESSION

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.6
# Mean squared error : 56.0
# Root Mean squared error : 7.483314773547883
#  R2 Score :
# -162.17228464419472

# %%
score=cross_val_score(dtr,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',dtr,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -1.4181133368476544
# Difference in R2 & CV Score: -20.36095095942929

# %% [markdown]
# # 5.) EXTRA TREE REGRESSION

# %%
etc=ExtraTreesRegressor()
etc.fit(x_train,y_train)
pred=etc.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 5.364
# Mean squared error : 51.608039999999995
# Root Mean squared error : 7.183873606905957
#  R2 Score :
# -141.61067415730332

# %%
score=cross_val_score(etc,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',etc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : -22.40605264330851
# Difference in R2 & CV Score: 2098.9945901735473

# %% [markdown]
# # 6.)XGBOOST REGRESSION

# %%
xg=XGBRegressor()
xg.fit(x_train,y_train)
pred=xg.predict(x_test)

# %%
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,pred))
print('Mean squared error :', mean_squared_error(y_test,pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(y_test,pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(y_test,pred)*100)
# Out:
# Error :
# Mean absolute error : 3.1543914794921877
# Mean squared error : 17.270976902147233
# Root Mean squared error : 4.15583648645459
#  R2 Score :
# 19.143366562981136

# %%
score=cross_val_score(xg,x,y,cv=5)
print('\033[1m'+'Cross Validation Score :',xg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
print('Difference in R2 & CV Score:',(r2_score(y_test,pred)*100)-(score.mean()*100))
# Out:
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None) :
#
# Mean CV Score : -11.752054643031663
# Difference in R2 & CV Score: 1194.3488308661474

# %% [markdown]
# # HYPER PARAMETER TUNING: GRIDSEARCHCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import numpy as np

# Define the hyperparameters to tune
n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

# Define the search space
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 500, 1000],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
}

# Create an XGBoost Regression model
xgb_model = XGBRegressor()

# Perform random search cross-validation
xgb_random = RandomizedSearchCV(estimator=xgb_model, param_distributions=param_grid,
                               n_iter=100, cv=5, verbose=2, random_state=42, n_jobs=-1,
                               scoring='neg_mean_squared_error')

# Fit the random search model
xgb_random.fit(x_train, y_train)

# Print the best hyperparameters found
print(xgb_random.best_params_)

# Evaluate the model
y_pred = xgb_random.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'subsample': 0.8, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 1.0}
# Mean Squared Error: 10.27

# %%
xgb = XGBRegressor(subsample=0.8, n_estimators=500, max_depth=3, learning_rate=0.01, colsample_bytree=1.0)

# Train the model on the entire training dataset
xgb.fit(x_train, y_train)

# Make predictions on new data
y_pred = xgb.predict(x_test)

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib
joblib.dump(xgb,"Zomato_restaurant_DATASET.pkl")
# Out:
# ['Zomato_restaurant_DATASET.pkl']

# %% [markdown]
# # PREDICTION

# %%
model = joblib.load("Zomato_restaurant_DATASET.pkl")

# Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([11.00895 , 16.933697, 10.446406,  9.199907, 12.941975],
#       dtype=float32)

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                   0          1          2          3          4
# Predicted  11.00895  16.933697  10.446406   9.199907  12.941975
# Original   11.00000  20.000000   8.000000  10.000000   7.000000

# %% [markdown]
# # END PROJECT

# %% [markdown]
# # THANK YOU
